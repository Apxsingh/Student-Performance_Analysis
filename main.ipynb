# %% [markdown]
# ## Student Performance Analysis
# ### Data Preprocessing & Visualization

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Step 1: Load Dataset
print("Loading Dataset...\n")

df = pd.read_csv(r"C:\Users\singh\OneDrive\Documents\student_data.csv")

# Display first 5 rows
print("First 5 Rows:")
print(df.head())
# Out:
# Loading Dataset...
#
# First 5 Rows:
#      Name  Math  Science  English  Attendance  StudyHours
# 0   Arpit    78       82       75          90           3
# 1   Rahul    65       70       60          80           2
# 2   Priya    88       91       85          95           5
# 3  Anjali    92       89       94          97           6
# 4   Rohan    55       60       58          70           1

# %%
# Step 2: Basic Information

print("\nDataset Information:")
print(df.info())

print("\nDataset Shape:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     object
#  1   Math        20 non-null     int64
#  2   Science     20 non-null     int64
#  3   English     20 non-null     int64
#  4   Attendance  20 non-null     int64
#  5   StudyHours  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB
# None
#
# Dataset Shape:
# (20, 6)
#
# Column Names:
# Index(['Name', 'Math', 'Science', 'English', 'Attendance', 'StudyHours'], dtype='object')

# %%
# Step 3: Statistical Summary

print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#             Math   Science    English  Attendance  StudyHours
# count  20.000000  20.00000  20.000000   20.000000   20.000000
# mean   77.450000  79.00000  77.500000   87.400000    3.750000
# std    12.279529  11.47996  12.352285    8.139572    1.773341
# min    55.000000  60.00000  58.000000   70.000000    1.000000
# 25%    67.750000  69.50000  69.750000   81.750000    2.000000
# 50%    77.000000  78.00000  76.500000   87.500000    3.000000
# 75%    89.250000  89.50000  89.250000   95.000000    5.250000
# max    95.000000  97.00000  96.000000   99.000000    7.000000

# %%
# Step 4: Check Missing Values

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Name          0
# Math          0
# Science       0
# English       0
# Attendance    0
# StudyHours    0
# dtype: int64

# %%
# Step 5: Remove Duplicate Rows

duplicates = df.duplicated().sum()
print(f"\nDuplicate Rows: {duplicates}")

df.drop_duplicates(inplace=True)
# Out:
# Duplicate Rows: 0

# %%
# Step 6: Add Average Marks Column

df["AverageMarks"] = (
    df["Math"] +
    df["Science"] +
    df["English"]
) / 3

print("\nDataset with Average Marks:")
print(df.head())
# Out:
# Dataset with Average Marks:
#      Name  Math  Science  English  Attendance  StudyHours  AverageMarks
# 0   Arpit    78       82       75          90           3     78.333333
# 1   Rahul    65       70       60          80           2     65.000000
# 2   Priya    88       91       85          95           5     88.000000
# 3  Anjali    92       89       94          97           6     91.666667
# 4   Rohan    55       60       58          70           1     57.666667

# %%
# Step 7: Find Top Performer

top_student = df.loc[df["AverageMarks"].idxmax()]

print("\nTop Performer:")
print(top_student)
# Out:
# Top Performer:
# Name            Isha
# Math              95
# Science           97
# English           96
# Attendance        99
# StudyHours         7
# AverageMarks    96.0
# Name: 13, dtype: object

# %%
# Step 8: Visualization

# Bar Chart
plt.figure(figsize=(10, 5))

plt.bar(df["Name"], df["Math"])

plt.title("Math Scores of Students")
plt.xlabel("Students")
plt.ylabel("Math Marks")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# Line Graph
plt.figure(figsize=(10, 5))

plt.plot(df["Name"], df["Attendance"], marker='o')

plt.title("Attendance of Students")
plt.xlabel("Students")
plt.ylabel("Attendance Percentage")

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# Histogram
plt.figure(figsize=(8, 5))

plt.hist(df["Science"], bins=5)

plt.title("Science Marks Distribution")
plt.xlabel("Science Marks")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# Pie Chart
study_hours = df["StudyHours"].value_counts()

plt.figure(figsize=(7, 7))

plt.pie(
    study_hours,
    labels=study_hours.index,
    autopct='%1.1f%%'
)

plt.title("Study Hours Distribution")

plt.show()

# %%
# Step 9: Insights

print("\n Insights ")

high_attendance = df[df["Attendance"] > 90]

print(
    f"Students with attendance above 90%: "
    f"{len(high_attendance)}"
)

avg_study = df["StudyHours"].mean()

print(f"Average Study Hours: {avg_study:.2f}")

avg_marks = df["AverageMarks"].mean()

print(f"Average Marks of Class: {avg_marks:.2f}")

print("\nProject Completed Successfully!")
# Out:
#  Insights
# Students with attendance above 90%: 7
# Average Study Hours: 3.75
# Average Marks of Class: 77.98
#
# Project Completed Successfully!
